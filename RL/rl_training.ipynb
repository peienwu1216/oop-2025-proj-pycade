# %%
import numpy as np
import pygame
import torch
import torch.nn as nn
import torch.optim as optim
import random
from collections import deque
import sys
import os
import os
# print(os.listdir("/Users/zhangbaifeng/Documents/交大/課程資料/大三（下）/物件導向程式設計/oop-2025-proj-pycade"))

sys.path.append(os.path.abspath(".."))
from game import Game 


# ---------- Environment -----------
class RLGameEnv:
    def __init__(self, render_mode=False):
        pygame.init()
        self.screen = pygame.display.set_mode((640, 480))
        self.clock = pygame.time.Clock()
        self.render_mode = render_mode
        self.game = Game(self.screen, self.clock, ai_archetype="rl")
        self.action_space = 5  # e.g., 0:stay, 1:up, 2:down, 3:left, 4:right
        self.state_dim = (10,)  # 依據你的觀察空間設計（這只是範例）

    def reset(self):
        self.game.setup_initial_state()
        return self.get_state()

    def step(self, action):
        # --- 將 action 應用到 AI 玩家上 ---
        if self.game.player2_ai and self.game.player2_ai.is_alive:
            self.apply_action(action)

        self.game.update()
        state = self.get_state()
        reward, done = self.compute_reward_done()
        return state, reward, done, {}

    def render(self):
        if self.render_mode:
            self.game.draw()
            pygame.display.flip()

    def get_state(self):
        # ⚠️ 請根據遊戲觀察資訊設計，例如：
        p2 = self.game.player2_ai
        p1 = self.game.player1
        if p2 is None or p1 is None:
            return np.zeros(self.state_dim, dtype=np.float32)
        state = np.array([
            p2.rect.x / 640, p2.rect.y / 480,
            p1.rect.x / 640, p1.rect.y / 480,
            p2.lives, p1.lives,
            p2.score / 100.0, p1.score / 100.0,
            self.game.time_elapsed_seconds / 60.0,
            int(p2.is_alive)
        ], dtype=np.float32)
        return state

    def compute_reward_done(self):
        done = self.game.game_state in ["GAME_OVER", "SCORE_SUBMITTED"]
        reward = 0.0
        if self.game.game_state == "GAME_OVER":
            if self.game.time_up_winner == "AI":
                reward = 1.0
            elif self.game.time_up_winner == "P1":
                reward = -1.0
            elif self.game.time_up_winner == "DRAW":
                reward = 0.5
        return reward, done

    def apply_action(self, action):
        ai = self.game.player2_ai
        if not ai:
            return
        if action == 0:
            pass  # stay
        elif action == 1:
            ai.move(0, -1)
        elif action == 2:
            ai.move(0, 1)
        elif action == 3:
            ai.move(-1, 0)
        elif action == 4:
            ai.move(1, 0)

# ---------- Q Network ----------
class QNetwork(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(QNetwork, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(state_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, action_dim)
        )

    def forward(self, x):
        return self.model(x)


# ---------- DQN Agent ----------
class DQNAgent:
    def __init__(self, state_dim, action_dim, lr=1e-3, gamma=0.99, epsilon=1.0, epsilon_min=0.1, epsilon_decay=0.995):
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.q_net = QNetwork(state_dim, action_dim)
        self.target_net = QNetwork(state_dim, action_dim)
        self.target_net.load_state_dict(self.q_net.state_dict())
        self.optimizer = optim.Adam(self.q_net.parameters(), lr=lr)
        self.memory = deque(maxlen=10000)
        self.batch_size = 64
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay
        self.update_target_steps = 100
        self.step_count = 0
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.q_net.to(self.device)
        self.target_net.to(self.device)

    def select_action(self, state):
        if np.random.rand() < self.epsilon:
            return np.random.randint(self.action_dim)
        state_tensor = torch.FloatTensor(state).unsqueeze(0).to(self.device)
        with torch.no_grad():
            q_values = self.q_net(state_tensor)
        return q_values.argmax().item()

    def store(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def train_step(self):
        if len(self.memory) < self.batch_size:
            return
        batch = random.sample(self.memory, self.batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)

        states = torch.FloatTensor(states).to(self.device)
        actions = torch.LongTensor(actions).unsqueeze(1).to(self.device)
        rewards = torch.FloatTensor(rewards).unsqueeze(1).to(self.device)
        next_states = torch.FloatTensor(next_states).to(self.device)
        dones = torch.FloatTensor(dones).unsqueeze(1).to(self.device)

        q_values = self.q_net(states).gather(1, actions)
        with torch.no_grad():
            max_next_q = self.target_net(next_states).max(1)[0].unsqueeze(1)
            target_q = rewards + (1 - dones) * self.gamma * max_next_q

        loss = nn.MSELoss()(q_values, target_q)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        # Epsilon decay
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

        # 更新 target net
        self.step_count += 1
        if self.step_count % self.update_target_steps == 0:
            self.target_net.load_state_dict(self.q_net.state_dict())

# ---------- Training Loop ----------
def train(env, num_episodes=1000):
    agent = DQNAgent(state_dim=env.state_dim[0], action_dim=env.action_space)
    rewards_log = []

    for episode in range(num_episodes):
        state = env.reset()
        total_reward = 0
        done = False

        while not done:
            action = agent.select_action(state)
            next_state, reward, done, _ = env.step(action)
            agent.store(state, action, reward, next_state, done)
            agent.train_step()
            state = next_state
            total_reward += reward
            if env.render_mode:
                env.render()

        rewards_log.append(total_reward)
        print(f"Episode {episode+1}/{num_episodes} - Reward: {total_reward:.2f} - Epsilon: {agent.epsilon:.2f}")

        # 每 50 回合存一次模型
        if (episode + 1) % 50 == 0:
            torch.save(agent.q_net.state_dict(), f"dqn_model_episode{episode+1}.pt")

    return rewards_log

if __name__ == "__main__":
    env = RLGameEnv(render_mode=False)
    train(env, num_episodes=500)
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.8.19)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# [MapManager DEBUG] Final generated map_data in get_randomized_map_layout:
# Row 00: WWWWWWWWWWWWWWW
# Row 01: W....D.DDDDD..W
# Row 02: W.W.WDWDW.W.W.W
# Row 03: W...D....DD..DW
# Row 04: WDWDW.W.WDW.W.W
# Row 05: WD.DD.D..D..DDW
# Row 06: W.WDWDW.WDWDWDW
# Row 07: W.D...DD......W
# Row 08: WDW.W.WDW.W.W.W
# Row 09: WD..D...DDD...W
# Row 10: WWWWWWWWWWWWWWW
# [MapManager DEBUG] map_data loaded in load_map_from_data:
# Row 00: WWWWWWWWWWWWWWW
# Row 01: W....D.DDDDD..W
# Row 02: W.W.WDWDW.W.W.W
# Row 03: W...D....DD..DW
# Row 04: WDWDW.W.WDW.W.W
# Row 05: WD.DD.D..D..DDW
# Row 06: W.WDWDW.WDWDWDW
# Row 07: W.D...DD......W
# Row 08: WDW.W.WDW.W.W.W
# Row 09: WD..D...DDD...W
# Row 10: WWWWWWWWWWWWWWW
# [AI_INIT] AIController for Player ID: 2111109808864 initialized. Initial state: PLANNING_PATH_TO_PLAYER. Debug Mode: True
# [AI_RESET] Resetting AI state for Player ID: 2111109808864.
# [AI_RESET] Target player initial spawn tile set to: (1, 1)
# [AI_RESET] Resetting AI state for Player ID: 2111109808864.
# [AI_RESET] Target player initial spawn tile set to: (1, 1)
# [MapManager DEBUG] Final generated map_data in get_randomized_map_layout:
# Row 00: WWWWWWWWWWWWWWW
# Row 01: W....DDD.DD.DDW
# Row 02: W.W.W.W.W.W.W.W
# Row 03: W....D......D.W
# Row 04: W.W.WDW.W.WDW.W
# Row 05: WDDDDD........W
# Row 06: W.WDW.W.W.W.WDW
# Row 07: WD....DDD.D...W
# Row 08: WDWDWDW.W.W.W.W
# Row 09: W...D.D.D.D...W
# Row 10: WWWWWWWWWWWWWWW
# [MapManager DEBUG] map_data loaded in load_map_from_data:
# Row 00: WWWWWWWWWWWWWWW
# Row 01: W....DDD.DD.DDW
# Row 02: W.W.W.W.W.W.W.W
# Row 03: W....D......D.W
# Row 04: W.W.WDW.W.WDW.W
# Row 05: WDDDDD........W
# Row 06: W.WDW.W.W.W.WDW
# Row 07: WD....DDD.D...W
# Row 08: WDWDWDW.W.W.W.W
# Row 09: W...D.D.D.D...W
# Row 10: WWWWWWWWWWWWWWW
# [AI_INIT] AIController for Player ID: 2111110561904 initialized. Initial state: PLANNING_PATH_TO_PLAYER. Debug Mode: True
# [AI_RESET] Resetting AI state for Player ID: 2111110561904.
# [AI_RESET] Target player initial spawn tile set to: (1, 1)
# [AI_RESET] Resetting AI state for Player ID: 2111110561904.
# [AI_RESET] Target player initial spawn tile set to: (1, 1)
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0
# [DEBUG_MOVE_FAIL] Player at (13, 9) trying to move to (13, 10).
#     Blocked by: <class 'sprites.wall.Wall'> sprite.
#     Obstacle rect: <rect(416, 320, 32, 32)>, its map coords should be: (13, 10)
#     Target check rect: <rect(416, 320, 32, 32)>
# [AI_HANDLER] PLANNING_PATH_TO_PLAYER at (13, 9)
# [AI_ASTAR] Planning path from (13, 9) to (1, 1)...
# [AI_ASTAR_SUCCESS] Path found (21 segments). Example segment: N(13,9,'.',g=0.0,h=20.0)
#   New A* path set, needs clearing. First segment: N(13,9,'.',g=0.0,h=20.0)
# [AI_STATE_CHANGE] ID: 2111110561904 From PLANNING_PATH_TO_PLAYER -> EXECUTING_PATH_CLEARANCE
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0
# [DEBUG_MOVE_FAIL] Player at (13, 9) trying to move to (14, 9).
#     Blocked by: <class 'sprites.wall.Wall'> sprite.
#     Obstacle rect: <rect(448, 288, 32, 32)>, its map coords should be: (14, 9)
#     Target check rect: <rect(448, 288, 32, 32)>
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0
# [DEBUG_ATTEMPT_MOVE] AI at (13,7), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE] AI at (13,7), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE] AI at (13,7), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE] AI at (13,7), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,7), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,7), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,7), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE] AI at (13,7), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE] AI at (13,7), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE] AI at (13,7), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0
# [DEBUG_ATTEMPT_MOVE] AI at (12,9), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE] AI at (12,9), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE] AI at (12,9), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (12,9), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (12,9), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (12,9), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (12,9), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (12,9), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.046999999999999945
# C:\Users\zhang\AppData\Local\Temp\ipykernel_17452\1540650120.py:144: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\tensor_new.cpp:281.)
#   states = torch.FloatTensor(states).to(self.device)
# [DEBUG_ATTEMPT_MOVE] AI at (12,9), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.029999999999999943
#   [AI_HANDLER] EXECUTING_PATH_CLEARANCE at (12, 9). Target A* node: N(13,9,'.',g=0.0,h=20.0)
#     Evaluating A* segment idx 0: N(13,9,'.',g=0.0,h=20.0) from AI tile (12, 9)
#       A* segment is EMPTY: N(13,9,'.',g=0.0,h=20.0). Setting sub-path to move.
#     Set new movement sub-path: [(12, 9), (13, 9)]
# [DEBUG_ATTEMPT_MOVE] AI at (12,9), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE] AI at (12,9), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0
# [DEBUG_MOVE_FAIL] Player at (12, 9) trying to move to (12, 10).
#     Blocked by: <class 'sprites.wall.Wall'> sprite.
#     Obstacle rect: <rect(384, 320, 32, 32)>, its map coords should be: (12, 10)
#     Target check rect: <rect(384, 320, 32, 32)>
# [DEBUG_ATTEMPT_MOVE] AI at (12,9), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0
#     Sub-path: Moved from (12, 9) to (13, 9). New index: 1
#     Sub-path to (13, 9) effectively completed by this move (AI is now on the target tile).
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.012999999999999942
#     Sub-path target (13, 9) reached. Path: [(12, 9), (13, 9)]. AI at: (13, 9)
#   [AI_HANDLER] EXECUTING_PATH_CLEARANCE at (13, 9). Target A* node: N(13,9,'.',g=0.0,h=20.0)
#     Evaluating A* segment idx 0: N(13,9,'.',g=0.0,h=20.0) from AI tile (13, 9)
#       AI is AT A* target node N(13,9,'.',g=0.0,h=20.0). Advancing A* path index.
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0
#   [AI_HANDLER] EXECUTING_PATH_CLEARANCE at (12, 9). Target A* node: N(13,8,'.',g=1.0,h=19.0)
#     Evaluating A* segment idx 1: N(13,8,'.',g=1.0,h=19.0) from AI tile (12, 9)
#       A* segment is EMPTY: N(13,8,'.',g=1.0,h=19.0). Setting sub-path to move.
#     Set new movement sub-path: [(12, 9), (13, 9), (13, 8)]
# [DEBUG_ATTEMPT_MOVE] AI at (12,9), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE] AI at (12,9), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE] AI at (12,9), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE] AI at (12,9), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (12,9), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (12,9), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (12,9), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (12,9), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (12,9), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE] AI at (12,9), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE] AI at (12,9), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE] AI at (12,9), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0
# [DEBUG_MOVE_FAIL] Player at (13, 9) trying to move to (14, 9).
#     Blocked by: <class 'sprites.wall.Wall'> sprite.
#     Obstacle rect: <rect(448, 288, 32, 32)>, its map coords should be: (14, 9)
#     Target check rect: <rect(448, 288, 32, 32)>
# [AI_MOVE_SUB_PATH_WARN] AI at (13, 9) but sub-path expected (12, 9) at index 0. Current sub_path: [(12, 9), (13, 9), (13, 8)]. Resetting sub-path.
#   [AI_HANDLER] EXECUTING_PATH_CLEARANCE at (13, 9). Target A* node: N(13,8,'.',g=1.0,h=19.0)
#     Evaluating A* segment idx 1: N(13,8,'.',g=1.0,h=19.0) from AI tile (13, 9)
#       A* segment is EMPTY: N(13,8,'.',g=1.0,h=19.0). Setting sub-path to move.
#     Set new movement sub-path: [(13, 9), (13, 8)]
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0
#     Sub-path: Moved from (13, 9) to (13, 8). New index: 1
#     Sub-path to (13, 8) effectively completed by this move (AI is now on the target tile).
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE] AI at (13,9), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0
# [DEBUG_MOVE_FAIL] Player at (13, 8) trying to move to (14, 8).
#     Blocked by: <class 'sprites.wall.Wall'> sprite.
#     Obstacle rect: <rect(448, 256, 32, 32)>, its map coords should be: (14, 8)
#     Target check rect: <rect(448, 256, 32, 32)>
#     Sub-path target (13, 8) reached. Path: [(13, 9), (13, 8)]. AI at: (13, 8)
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0
# [DEBUG_MOVE_FAIL] Player at (13, 8) trying to move to (14, 8).
#     Blocked by: <class 'sprites.wall.Wall'> sprite.
#     Obstacle rect: <rect(448, 256, 32, 32)>, its map coords should be: (14, 8)
#     Target check rect: <rect(448, 256, 32, 32)>
#   [AI_HANDLER] EXECUTING_PATH_CLEARANCE at (13, 8). Target A* node: N(13,8,'.',g=1.0,h=19.0)
#     Evaluating A* segment idx 1: N(13,8,'.',g=1.0,h=19.0) from AI tile (13, 8)
#       AI is AT A* target node N(13,8,'.',g=1.0,h=19.0). Advancing A* path index.
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0
# [DEBUG_MOVE_FAIL] Player at (13, 8) trying to move to (12, 8).
#     Blocked by: <class 'sprites.wall.Wall'> sprite.
#     Obstacle rect: <rect(384, 256, 32, 32)>, its map coords should be: (12, 8)
#     Target check rect: <rect(384, 256, 32, 32)>
#   [AI_HANDLER] EXECUTING_PATH_CLEARANCE at (13, 8). Target A* node: N(13,7,'.',g=2.0,h=18.0)
#     Evaluating A* segment idx 2: N(13,7,'.',g=2.0,h=18.0) from AI tile (13, 8)
#       A* segment is EMPTY: N(13,7,'.',g=2.0,h=18.0). Setting sub-path to move.
#     Set new movement sub-path: [(13, 8), (13, 7)]
# [DEBUG_ATTEMPT_MOVE] AI at (13,8), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0
#     Sub-path: Moved from (13, 8) to (13, 7). New index: 1
#     Sub-path to (13, 7) effectively completed by this move (AI is now on the target tile).
# [DEBUG_ATTEMPT_MOVE] AI at (13,7), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE] AI at (13,7), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE] AI at (13,7), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,7), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,7), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (13,7), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE] AI at (13,7), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE] AI at (13,7), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.012999999999999942
#     Sub-path target (13, 7) reached. Path: [(13, 8), (13, 7)]. AI at: (13, 7)
#   [AI_HANDLER] EXECUTING_PATH_CLEARANCE at (13, 7). Target A* node: N(13,7,'.',g=2.0,h=18.0)
#     Evaluating A* segment idx 2: N(13,7,'.',g=2.0,h=18.0) from AI tile (13, 7)
#       AI is AT A* target node N(13,7,'.',g=2.0,h=18.0). Advancing A* path index.
# [DEBUG_ATTEMPT_MOVE] AI at (13,7), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0
#   [AI_HANDLER] EXECUTING_PATH_CLEARANCE at (12, 7). Target A* node: N(12,7,'.',g=3.0,h=17.0)
#     Evaluating A* segment idx 3: N(12,7,'.',g=3.0,h=17.0) from AI tile (12, 7)
#       AI is AT A* target node N(12,7,'.',g=3.0,h=17.0). Advancing A* path index.
# [DEBUG_ATTEMPT_MOVE] AI at (12,7), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.183
#   [AI_HANDLER] EXECUTING_PATH_CLEARANCE at (12, 7). Target A* node: N(11,7,'.',g=4.0,h=16.0)
#     Evaluating A* segment idx 4: N(11,7,'.',g=4.0,h=16.0) from AI tile (12, 7)
#       A* segment is EMPTY: N(11,7,'.',g=4.0,h=16.0). Setting sub-path to move.
#     Set new movement sub-path: [(12, 7), (11, 7)]
# [DEBUG_ATTEMPT_MOVE] AI at (12,7), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE] AI at (12,7), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (12,7), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (12,7), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE] AI at (12,7), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE] AI at (12,7), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE] AI at (12,7), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0
# [DEBUG_ATTEMPT_MOVE] AI at (11,7), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE] AI at (11,7), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE] AI at (11,7), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (11,7), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (11,7), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE] AI at (11,7), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.012999999999999942
#     Sub-path target (11, 7) reached. Path: [(12, 7), (11, 7)]. AI at: (11, 7)
# [DEBUG_ATTEMPT_MOVE] AI at (11,7), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0
# [DEBUG_MOVE_FAIL] Player at (11, 7) trying to move to (10, 7).
#     Blocked by: <class 'sprites.wall.DestructibleWall'> sprite.
#     Obstacle rect: <rect(320, 224, 32, 32)>, its map coords should be: (10, 7)
#     Target check rect: <rect(320, 224, 32, 32)>
#   [AI_HANDLER] EXECUTING_PATH_CLEARANCE at (11, 7). Target A* node: N(11,7,'.',g=4.0,h=16.0)
#     Evaluating A* segment idx 4: N(11,7,'.',g=4.0,h=16.0) from AI tile (11, 7)
#       AI is AT A* target node N(11,7,'.',g=4.0,h=16.0). Advancing A* path index.
# [DEBUG_ATTEMPT_MOVE] AI at (11,7), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0
#   [AI_HANDLER] EXECUTING_PATH_CLEARANCE at (11, 8). Target A* node: N(11,6,'.',g=5.0,h=15.0)
#     Evaluating A* segment idx 5: N(11,6,'.',g=5.0,h=15.0) from AI tile (11, 8)
#       A* segment is EMPTY: N(11,6,'.',g=5.0,h=15.0). Setting sub-path to move.
#     Set new movement sub-path: [(11, 8), (11, 7), (11, 6)]
# [DEBUG_ATTEMPT_MOVE] AI at (11,8), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (11,8), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (11,8), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (11,8), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (11,8), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE] AI at (11,8), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE] AI at (11,8), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0
#     Sub-path: Moved from (11, 8) to (11, 7). New index: 1
# [DEBUG_ATTEMPT_MOVE] AI at (11,7), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE] AI at (11,7), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (11,7), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (11,7), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE] AI at (11,7), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0
#     Sub-path: Moved from (11, 7) to (11, 6). New index: 2
#     Sub-path to (11, 6) effectively completed by this move (AI is now on the target tile).
# [DEBUG_ATTEMPT_MOVE] AI at (11,6), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE] AI at (11,6), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE] AI at (11,6), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (11,6), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (11,6), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE] AI at (11,6), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE] AI at (11,6), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE] AI at (11,6), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0
# [DEBUG_MOVE_FAIL] Player at (11, 6) trying to move to (10, 6).
#     Blocked by: <class 'sprites.wall.Wall'> sprite.
#     Obstacle rect: <rect(320, 192, 32, 32)>, its map coords should be: (10, 6)
#     Target check rect: <rect(320, 192, 32, 32)>
#     Sub-path target (11, 6) reached. Path: [(11, 8), (11, 7), (11, 6)]. AI at: (11, 6)
# [DEBUG_ATTEMPT_MOVE] AI at (11,6), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0
# [DEBUG_MOVE_FAIL] Player at (11, 6) trying to move to (10, 6).
#     Blocked by: <class 'sprites.wall.Wall'> sprite.
#     Obstacle rect: <rect(320, 192, 32, 32)>, its map coords should be: (10, 6)
#     Target check rect: <rect(320, 192, 32, 32)>
#   [AI_HANDLER] EXECUTING_PATH_CLEARANCE at (11, 6). Target A* node: N(11,6,'.',g=5.0,h=15.0)
#     Evaluating A* segment idx 5: N(11,6,'.',g=5.0,h=15.0) from AI tile (11, 6)
#       AI is AT A* target node N(11,6,'.',g=5.0,h=15.0). Advancing A* path index.
#   [AI_HANDLER] EXECUTING_PATH_CLEARANCE at (11, 6). Target A* node: N(11,5,'.',g=6.0,h=14.0)
#     Evaluating A* segment idx 6: N(11,5,'.',g=6.0,h=14.0) from AI tile (11, 6)
#       A* segment is EMPTY: N(11,5,'.',g=6.0,h=14.0). Setting sub-path to move.
#     Set new movement sub-path: [(11, 6), (11, 5)]
# [DEBUG_ATTEMPT_MOVE] AI at (11,6), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0
#     Sub-path: Moved from (11, 6) to (11, 5). New index: 1
#     Sub-path to (11, 5) effectively completed by this move (AI is now on the target tile).
# [DEBUG_ATTEMPT_MOVE] AI at (11,5), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE] AI at (11,5), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE] AI at (11,5), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (11,5), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (11,5), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE] AI at (11,5), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE] AI at (11,5), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE] AI at (11,5), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0
# [DEBUG_ATTEMPT_MOVE] AI at (12,5), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE] AI at (12,5), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE] AI at (12,5), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (12,5), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (12,5), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (12,5), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (12,5), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (12,5), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE] AI at (12,5), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE] AI at (12,5), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE] AI at (12,5), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0
# [DEBUG_ATTEMPT_MOVE] AI at (11,5), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE] AI at (11,5), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE] AI at (11,5), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (11,5), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (11,5), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (11,5), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.046999999999999945
#     Sub-path target (11, 5) reached. Path: [(11, 6), (11, 5)]. AI at: (11, 5)
# [DEBUG_ATTEMPT_MOVE] AI at (11,5), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0
#   [AI_HANDLER] EXECUTING_PATH_CLEARANCE at (10, 5). Target A* node: N(11,5,'.',g=6.0,h=14.0)
# ...
# [DEBUG_MOVE_FAIL] Player at (1, 4) trying to move to (0, 4).
#     Blocked by: <class 'sprites.wall.Wall'> sprite.
#     Obstacle rect: <rect(0, 128, 32, 32)>, its map coords should be: (0, 4)
#     Target check rect: <rect(0, 128, 32, 32)>
# [DEBUG_ATTEMPT_MOVE] AI at (1,4), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0
# [DEBUG_MOVE_FAIL] Player at (1, 4) trying to move to (2, 4).
#     Blocked by: <class 'sprites.wall.Wall'> sprite.
#     Obstacle rect: <rect(64, 128, 32, 32)>, its map coords should be: (2, 4)
#     Target check rect: <rect(64, 128, 32, 32)>
# [DEBUG_ATTEMPT_MOVE] AI at (1,4), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0
# [DEBUG_MOVE_FAIL] Player at (1, 4) trying to move to (2, 4).
#     Blocked by: <class 'sprites.wall.Wall'> sprite.
#     Obstacle rect: <rect(64, 128, 32, 32)>, its map coords should be: (2, 4)
#     Target check rect: <rect(64, 128, 32, 32)>
# [DEBUG_ATTEMPT_MOVE] AI at (1,4), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0
# [DEBUG_MOVE_FAIL] Player at (1, 4) trying to move to (0, 4).
#     Blocked by: <class 'sprites.wall.Wall'> sprite.
#     Obstacle rect: <rect(0, 128, 32, 32)>, its map coords should be: (0, 4)
#     Target check rect: <rect(0, 128, 32, 32)>
# [DEBUG_ATTEMPT_MOVE] AI at (1,4), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0
# [DEBUG_ATTEMPT_MOVE] AI at (1,4), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (1,4), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (1,4), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (1,4), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (1,4), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE] AI at (1,4), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE] AI at (1,4), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE] AI at (1,4), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0
# [DEBUG_MOVE_FAIL] Player at (1, 4) trying to move to (2, 4).
#     Blocked by: <class 'sprites.wall.Wall'> sprite.
#     Obstacle rect: <rect(64, 128, 32, 32)>, its map coords should be: (2, 4)
#     Target check rect: <rect(64, 128, 32, 32)>
# [DEBUG_ATTEMPT_MOVE] AI at (1,4), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0
# [DEBUG_MOVE_FAIL] Player at (1, 4) trying to move to (0, 4).
#     Blocked by: <class 'sprites.wall.Wall'> sprite.
#     Obstacle rect: <rect(0, 128, 32, 32)>, its map coords should be: (0, 4)
#     Target check rect: <rect(0, 128, 32, 32)>
# [DEBUG_ATTEMPT_MOVE] AI at (1,4), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.183
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.11499999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0
# [DEBUG_ATTEMPT_MOVE] AI at (1,4), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE] AI at (1,4), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (1,4), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.09799999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (1,4), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.08099999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (1,4), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (1,4), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE] AI at (1,4), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE] AI at (1,4), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE] AI at (1,4), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0
# [DEBUG_MOVE_FAIL] Player at (1, 4) trying to move to (0, 4).
#     Blocked by: <class 'sprites.wall.Wall'> sprite.
#     Obstacle rect: <rect(0, 128, 32, 32)>, its map coords should be: (0, 4)
#     Target check rect: <rect(0, 128, 32, 32)>
# [DEBUG_ATTEMPT_MOVE] AI at (1,4), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.16599999999999998
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.16599999999999998
# [AI_HANDLER] ENGAGING_PLAYER at (1, 3)
#   ENGAGE_INFO: AI Bombs: 0/1, Range: 1
#   ENGAGE: AI at (1, 3) is very close (dist: 2) to human at (1, 1). Switching to CLOSE_QUARTERS_COMBAT.
# [AI_STATE_CHANGE] ID: 2111110561904 From ENGAGING_PLAYER -> CLOSE_QUARTERS_COMBAT
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=1, dy=0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.14899999999999997
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.13199999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.06399999999999995
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.046999999999999945
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=0, dy=1. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.029999999999999943
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=0, dy=-1. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE_FAIL] Reason: Not alive or action_timer > 0. IsAlive: True, ActionTimer: 0.012999999999999942
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0
# [DEBUG_MOVE_FAIL] Player at (1, 3) trying to move to (0, 3).
#     Blocked by: <class 'sprites.wall.Wall'> sprite.
#     Obstacle rect: <rect(0, 96, 32, 32)>, its map coords should be: (0, 3)
#     Target check rect: <rect(0, 96, 32, 32)>
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0
# [DEBUG_MOVE_FAIL] Player at (1, 3) trying to move to (0, 3).
#     Blocked by: <class 'sprites.wall.Wall'> sprite.
#     Obstacle rect: <rect(0, 96, 32, 32)>, its map coords should be: (0, 3)
#     Target check rect: <rect(0, 96, 32, 32)>
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0
# [DEBUG_MOVE_FAIL] Player at (1, 3) trying to move to (0, 3).
#     Blocked by: <class 'sprites.wall.Wall'> sprite.
#     Obstacle rect: <rect(0, 96, 32, 32)>, its map coords should be: (0, 3)
#     Target check rect: <rect(0, 96, 32, 32)>
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0
# [DEBUG_MOVE_FAIL] Player at (1, 3) trying to move to (0, 3).
#     Blocked by: <class 'sprites.wall.Wall'> sprite.
#     Obstacle rect: <rect(0, 96, 32, 32)>, its map coords should be: (0, 3)
#     Target check rect: <rect(0, 96, 32, 32)>
# [DEBUG_ATTEMPT_MOVE] AI at (1,3), trying dx=-1, dy=0. IsAlive: True, ActionTimer: 0
# [DEBUG_MOVE_FAIL] Player at (1, 3) trying to move to (0, 3).
#     Blocked by: <class 'sprites.wall.Wall'> sprite.
#     Obstacle rect: <rect(0, 96, 32, 32)>, its map coords should be: (0, 3)
#     Target check rect: <rect(0, 96, 32, 32)>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 200
#     198 if __name__ == "__main__":
#     199     env = RLGameEnv(render_mode=False)
# --> 200     train(env, num_episodes=500)
#
# Cell In[1], line 183, in train(env, num_episodes)
#     181 next_state, reward, done, _ = env.step(action)
#     182 agent.store(state, action, reward, next_state, done)
# --> 183 agent.train_step()
#     184 state = next_state
#     185 total_reward += reward
#
# Cell In[1], line 157, in DQNAgent.train_step(self)
#     155 loss = nn.MSELoss()(q_values, target_q)
#     156 self.optimizer.zero_grad()
# --> 157 loss.backward()
#     158 self.optimizer.step()
#     160 # Epsilon decay
#
# File c:\Users\zhang\anaconda3\envs\torch\lib\site-packages\torch\_tensor.py:521, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     511 if has_torch_function_unary(self):
#     512     return handle_torch_function(
#     513         Tensor.backward,
#     514         (self,),
#    (...)
#     519         inputs=inputs,
#     520     )
# --> 521 torch.autograd.backward(
#     522     self, gradient, retain_graph, create_graph, inputs=inputs
#     523 )
#
# File c:\Users\zhang\anaconda3\envs\torch\lib\site-packages\torch\autograd\__init__.py:282, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     273 inputs = (
#     274     (inputs,)
#     275     if isinstance(inputs, (torch.Tensor, graph.GradientEdge))
#    (...)
#     278     else tuple()
#     279 )
#     281 grad_tensors_ = _tensor_or_tensors_to_tuple(grad_tensors, len(tensors))
# --> 282 grad_tensors_ = _make_grads(tensors, grad_tensors_, is_grads_batched=False)
#     283 if retain_graph is None:
#     284     retain_graph = create_graph
#
# File c:\Users\zhang\anaconda3\envs\torch\lib\site-packages\torch\autograd\__init__.py:161, in _make_grads(outputs, grads, is_grads_batched)
#     155         msg = (
#     156             "grad can be implicitly created only for real scalar outputs"
#     157             f" but got {out.dtype}"
#     158         )
#     159         raise RuntimeError(msg)
#     160     new_grads.append(
# --> 161         torch.ones_like(out, memory_format=torch.preserve_format)
#     162     )
#     163 else:
#     164     new_grads.append(None)
#
# KeyboardInterrupt:
